# %% [markdown]
# Download Yolov7 repo

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...

# %% [markdown]
# Download modified Yolov7 object tracking repo

# %%
# !git clone https://github.com/haroonshakeel/yolov7-object-tracking.git
# Out:
# Cloning into 'yolov7-object-tracking'...

# %% [markdown]
# Copy the "detect_or_track.py", "requiremenrs.txt", "requiremenrs_gpu.txt" and "short.py" form yolov7-object-tracking and paste in to yolov7 folder

# %% [markdown]
# get into yolov7 directory

# %%
# %cd yolov7/
# Out:
# C:\Users\DELL\DOT-EYE\yolov7

# %% [markdown]
# Download all the dependencies

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached scipy-1.9.1-cp38-cp38-win_amd64.whl (38.6 MB)
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.3
#     Uninstalling scipy-1.9.3:
#       Successfully uninstalled scipy-1.9.3
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\python 3.8.10\\Lib\\site-packages\\~cipy.libs\\libopenblas-57db09cfe174768fb409a6bb5a530d4c.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 21.1.1; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\python 3.8.10\python.exe -m pip install --upgrade pip' command.

# %%
# %cd yolov7/
# Out:
# C:\Users\DELL\DOT-EYE\yolov7

# %% [markdown]
# Inferencing the given video

# %%
# !python detect_or_track.py --weights yolov7.pt --no-trace --view-img --source street.mp4 --show-fps --seed 2 --track --classes 0 --show-track
# Out:
# ^C

# %%
# !python detect_or_track.py --weights yolov7.pt --no-trace --view-img --source try.mp4 --show-fps --seed 2 --track --classes 0 --show-track
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=[0], conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=True, nobbox=False, nolabel=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, seed=2, show_fps=True, show_track=True, source='try.mp4', thickness=2, track=True, unique_track_color=False, update=False, view_img=True, weights=['yolov7.pt'])
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# video 1/1 (1/341) C:\Users\DELL\DOT-EYE\yolov7\try.mp4: 27 persons, Done. (771.7ms) Inference, (0.0ms) NMS
# video 1/1 (2/341) C:\Users\DELL\DOT-EYE\yolov7\try.mp4: 29 persons, Done. (860.7ms) Inference, (0.0ms) NMS
# video 1/1 (3/341) C:\Users\DELL\DOT-EYE\yolov7\try.mp4: 27 persons, Done. (803.4ms) Inference, (0.0ms) NMS
# video 1/1 (4/341) C:\Users\DELL\DOT-EYE\yolov7\try.mp4: 28 persons, Done. (819.8ms) Inference, (0.0ms) NMS
# ...
